# %% [markdown]
# FACE DETECTION

# %%
from ultralytics import YOLO

# Correct usage: pass model file name as a string
model1 = YOLO("./face-detection-yolov8/yolov8n-face.pt")

# %%
import cv2

# %%
cap = cv2.VideoCapture(0)

# %% [markdown]
# FACE DETECTION IN VIDEO

# %%
video_path = r"C:\Users\avinash\Downloads\my projects\Deep learning\cctv.mp4"

cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print('cannot open video')
    exit()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    results = model1(frame)[0]
    annotated = results.plot()
    cv2.imshow('Face Detection', annotated)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 158.1ms
# Speed: 4.4ms preprocess, 158.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 129.7ms
# Speed: 3.6ms preprocess, 129.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.0ms
# Speed: 5.0ms preprocess, 102.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.3ms
# Speed: 4.3ms preprocess, 90.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.9ms
# Speed: 3.9ms preprocess, 97.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.1ms
# Speed: 2.7ms preprocess, 101.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 103.8ms
# Speed: 3.0ms preprocess, 103.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\avinash\\Downloads\\my projects\\Deep learning'

# %%
import os
os.path.exists('gd.ipynb')
# Out:
# True

# %% [markdown]
# DETECT THE FACE BY GETTING THE VEDIO FROM THE USER

# %%
import tkinter as tk
from tkinter import filedialog
from ultralytics import YOLO
import cv2

# Hide the main tkinter window
root = tk.Tk()
root.withdraw()

# Ask the user to select a video file
video_path = filedialog.askopenfilename(
    title="Select Video File",
    filetypes=[("Video files", "*.mp4 *.avi *.mov *.mkv")]
)

if not video_path:
    print("No file selected.")
    exit()



# Open the selected video
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Error: Cannot open video.")
    exit()

# Process frames
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    results = model1(frame)[0]
    annotated = results.plot()
    cv2.imshow("Face Detection", annotated)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 80.2ms
# Speed: 4.8ms preprocess, 80.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.3ms
# Speed: 3.0ms preprocess, 100.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.4ms
# Speed: 2.1ms preprocess, 85.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.1ms
# Speed: 2.2ms preprocess, 89.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.5ms
# Speed: 2.1ms preprocess, 84.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.8ms
# Speed: 2.5ms preprocess, 95.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 137.1ms
# Speed: 3.9ms preprocess, 137.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %% [markdown]
# OBJECT DETECTION

# %%
import cv2
from ultralytics import YOLO

# Load pre-trained YOLOv8 model (YOLOv8n is fast, good for real-time)
model = YOLO('yolov8n.pt')  # You can also try 'yolov8s.pt' or others

# Open webcam (0 = default camera)
cap = cv2.VideoCapture(0)

# Check if webcam opened successfully
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Run detection loop
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv8 detection
    results = model(frame)[0]

    # Annotate frame with detections
    annotated_frame = results.plot()

    # Display the annotated frame
    cv2.imshow("Object Detection", annotated_frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 2 persons, 1 bottle, 98.2ms
# Speed: 3.0ms preprocess, 98.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 123.7ms
# Speed: 3.2ms preprocess, 123.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 116.7ms
# Speed: 4.6ms preprocess, 116.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 refrigerator, 102.3ms
# Speed: 3.7ms preprocess, 102.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 92.8ms
# Speed: 2.5ms preprocess, 92.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 refrigerator, 111.5ms
# Speed: 2.4ms preprocess, 111.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 refrigerator, 116.2ms
# ...

# %%
cv2.VideoCapture(0)
if not cap.isOpened:
    print('error opening in webcam')
while cap.isOpened:
    ret, frame = cap.read()
    if not ret:
        break
    results = model1(frame)[0]
    annot = results.plot()
    cv2.imshow('face detection', annot)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
